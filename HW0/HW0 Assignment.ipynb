# %% [markdown]
# This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.
#
# The goal is to write a function to count the frequency of different characters in a given string. For example: character_frequency('google') should return a `dict`: {'g': 2, 'o': 2, 'l': 1, 'e': 1}.
#
# There are many tutorials on the web that can show you how to use the Python data structures. Quite a few examples at: https://docs.python.org/3/tutorial/datastructures.html
#
#
# You should edit the function definition below, make sure to press 'Shift + Enter' to execute it, and then execute the two function calls to check that the output is correct.

# %%
def character_frequency(s):
    ret = dict()

    for char in s:
        if char in ret:
            ret[char] += 1
        else:
            ret[char] = 1
    return ret

# %%
character_frequency('google')
# Out:
# {'g': 2, 'o': 2, 'l': 1, 'e': 1}

# %%
character_frequency('This assignment is intended to ensure that you are able to edit and submit Jupyter Notebooks.')
# Out:
# {'T': 1,
#  'h': 2,
#  'i': 6,
#  's': 7,
#  ' ': 15,
#  'a': 5,
#  'g': 1,
#  'n': 6,
#  'm': 2,
#  'e': 10,
#  't': 10,
#  'd': 4,
#  'o': 6,
#  'u': 4,
#  'r': 3,
#  'y': 2,
#  'b': 3,
#  'l': 1,
#  'J': 1,
#  'p': 1,
#  'N': 1,
#  'k': 1,
#  '.': 1}

# %% [markdown]
# In Below, Provide GitHub Repository URL:

# %% [markdown]
# https://github.com/Giriprasad02/DATA602_FardinaAlam

# %% [markdown]
# In Below, GitHub Page URL:

# %% [markdown]
# https://giriprasad02.github.io/DATA602_FardinaAlam/

# %%
import sys

print("Name: Giriprasad Radhakrishnan")
print("Student ID: 121959751")
print("Python version:", sys.version)
print("Python is working successfully!")
# Out:
# Name: Giriprasad Radhakrishnan
# Student ID: 121959751
# Python version: 3.14.5 (tags/v3.14.5:5607950, May 10 2026, 10:43:50) [MSC v.1944 64 bit (AMD64)]
# Python is working successfully!

# %%
import torch

print("Name: Giriprasad Radhakrishnan")
print("Student ID: 121959751")
print("PyTorch Version:", torch.__version__)
print("GPU Available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# C:\Users\rssjh\AppData\Local\Programs\Python\Python314\Lib\site-packages\torch\_subclasses\functional_tensor.py:307: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# Name: Giriprasad Radhakrishnan
# Student ID: 121959751
# PyTorch Version: 2.11.0+cu128
# GPU Available: True
# GPU: NVIDIA GeForce RTX 5070 Ti Laptop GPU

# %% [markdown]
# Below, add the screenshots. You can include additional markdown or text cells if needed.

# %% [markdown]
# ### Local Python Setup
#
# ![Local Python](python_local.png)

# %% [markdown]
# ### Google Colab and PyTorch
#
# ![Google Colab PyTorch](colab_pytorch.png)

# %% [markdown]
# ###
#
# Local PyTorch GPU Setup
#
# ![Local PyTorch](pytorch_local.png)
